# %% [markdown]
# # UTKFace Image Dataset Analysis
#
# -----
#
# ## Pearson Correlations Of Contributing Image Segments To Classifications
#
# Here we detail the relationship between the image segments that contribute to age estimations, and the varying combinations of racial categories and age ranges. This is achieved by considering the percentage that each image segment contributes to the inference of a subject’s age. We aggregate the results for the entire sample and group them by racial categories and age ranges.
#
# Thereafter, we implement the Pearson correlation coefficient on all image segments of all subjects within their respective groups to determine how (anti)correlated said segments are to the determination of a subject’s age. We detail the correlations, and specifically filter for age estimations that returned accurate results.

# %%
import json
import numpy as np
import pandas as pd
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
plt.ioff()
# %matplotlib inline
from analysis_3_filter_visualise import *

# Load in the results for the UTKFace image activations dataset.
image_masks_fpath = "utkface/img-masks/"
utkface_data = json.loads(open("metadataset_utkface_activations.json").read())
utkface_data_face_vs_outer, utkface_data_contribution_pct = generate_processed_datasets(utkface_data)

# Generate the correlations
correlation_list = list()
for this_age_range in [[0,12], [13,18], [19,25], [26,100]]:
    for this_type in ["positive", "negative"]:
        correlation_list.extend(visualise_heatmap_corr_pairplot(filter_dataset(utkface_data_face_vs_outer[this_type], 
            KEYS_RACE_AGE_BOUNDARIES, "race_real", RACES, age_min=this_age_range[0], age_max=this_age_range[1]), image_masks_fpath, 
                                        x_vars=KEYS_BOUNDARIES, pairplot_scatter_alpha=0.025, age_range="%s - %s" % (this_age_range[0], this_age_range[1]), this_type=this_type))

# Produce the dataframe
pd.DataFrame(correlation_list)
# Out:
# WARNING: Cohort is small and may not be representative.
# WARNING: Cohort is small and may not be representative.
# WARNING: Cohort is small and may not be representative.
# WARNING: Cohort is small and may not be representative.
# WARNING: Cohort is small and may not be representative.
# WARNING: Cohort is small and may not be representative.
# WARNING: Cohort is small and may not be representative.
#         face  outer_boundary_left  outer_boundary_right  outer_boundary_top  \
# 0   0.016513             0.005753             -0.012306           -0.079399
# 1   0.102614             0.063821             -0.062802           -0.058457
# 2  -0.036242            -0.146797              0.041303           -0.092133
# 3   0.046936             0.050545             -0.080470           -0.112087
# 4   0.185341            -0.053459             -0.069378           -0.109960
# 5  -0.084793             0.004101              0.050588            0.026588
# 6  -0.043408            -0.075418              0.026560            0.059268
# 7  -0.071872            -0.093589              0.036649           -0.021509
# 8  -0.111061             0.052495              0.174075           -0.018333
# 9  -0.012457             0.011175             -0.012707           -0.004625
# 10  0.032793             0.007369             -0.034769           -0.048063
# 11 -0.141621             0.052226              0.053690            0.031668
# 12  0.031825            -0.273900              0.387784           -0.075039
# 13  0.116142             0.036889             -0.074237           -0.008286
# 14  0.048141             0.028366             -0.019924           -0.053086
# 15  0.089626             0.047996              0.118406            0.023406
# 16  0.209084             0.603465              0.320963           -0.256885
# 17  0.144996            -0.748094              0.567817           -0.208455
# 18 -0.297458            -0.074439              0.345663            0.398806
# 19 -0.263265             0.246469             -0.022824           -0.009831
# 20 -0.066475             0.055816             -0.041158           -0.090565
# 21  0.010861            -0.025669             -0.070932           -0.004353
# 22 -0.285590            -0.113007             -0.226865           -0.032351
# 23  0.055233            -0.077110             -0.053092           -0.049487
# 24  0.121214             0.000749              0.002378            0.062639
# 25  0.254735            -0.289906              0.121692            0.045627
# 26  0.241857            -0.173313             -0.184096            0.029786
# 27 -0.461959             0.392759              0.059409            0.125524
# 28  0.185259            -0.043939              0.209363           -0.220333
# 29 -0.118677             0.325911              0.164329           -0.155198
# 30 -0.022446             0.010858              0.000184           -0.049112
# 31 -0.036532             0.062315              0.009130            0.035976
# 32 -0.075520            -0.015781              0.102812           -0.027082
# 33 -0.061742            -0.008137              0.050209            0.031883
# 34 -0.012058             0.085287              0.006706            0.061511
# 35 -0.003944            -0.026563             -0.043222           -0.005470
# 36 -0.097643             0.166424             -0.119781           -0.060915
# 37 -0.024066            -0.088701             -0.062822            0.005935
# 38 -0.110980             0.070422             -0.027040            0.021787
# 39  0.005685            -0.326740              0.120476           -0.047403
#
#     outer_boundary_bottom       race age_range classification_type
# 0                0.080752  Caucasian    0 - 12            positive
# 1               -0.022206      Asian    0 - 12            positive
# 2                0.075251    African    0 - 12            positive
# 3                0.095438     Indian    0 - 12            positive
# 4                0.011903      Other    0 - 12            positive
# 5                0.043224  Caucasian    0 - 12            negative
# 6                0.037837      Asian    0 - 12            negative
# 7                0.054080    African    0 - 12            negative
# 8               -0.017884     Indian    0 - 12            negative
# 9                0.026115      Other    0 - 12            negative
# 10               0.042687  Caucasian   13 - 18            positive
# 11               0.017745      Asian   13 - 18            positive
# 12              -0.260066    African   13 - 18            positive
# 13              -0.092981     Indian   13 - 18            positive
# 14              -0.082754      Other   13 - 18            positive
# 15              -0.150406  Caucasian   13 - 18            negative
# 16              -0.529935      Asian   13 - 18            negative
# 17               0.083015    African   13 - 18            negative
# 18              -0.170759     Indian   13 - 18            negative
# 19               0.146029      Other   13 - 18            negative
# 20               0.114744  Caucasian   19 - 25            positive
# 21               0.076547      Asian   19 - 25            positive
# 22               0.718232    African   19 - 25            positive
# 23               0.074195     Indian   19 - 25            positive
# 24              -0.242108      Other   19 - 25            positive
# 25              -0.106138  Caucasian   19 - 25            negative
# 26               0.247695      Asian   19 - 25            negative
# 27               0.507071    African   19 - 25            negative
# 28              -0.195928     Indian   19 - 25            negative
# 29               0.061272      Other   19 - 25            negative
# 30               0.032376  Caucasian  26 - 100            positive
# 31              -0.034668      Asian  26 - 100            positive
# 32              -0.033532    African  26 - 100            positive
# 33               0.026523     Indian  26 - 100            positive
# 34              -0.103908      Other  26 - 100            positive
# 35               0.046869  Caucasian  26 - 100            negative
# 36               0.107392      Asian  26 - 100            negative
# 37               0.066323    African  26 - 100            negative
# 38               0.056529     Indian  26 - 100            negative
# 39               0.237321      Other  26 - 100            negative

# %% [markdown]
# ## Notes
#
# Beyond the correlations given here, we isolate results that contribute to Appendix B of our paper in the file Excel Worksheet entitled "Correlations_Image_Segment_Activations.xlsx"
